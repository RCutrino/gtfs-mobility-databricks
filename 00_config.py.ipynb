# %%
BASE_PATH = "/Volumes/workspace/default/gtfs-mobility/progetto databricks"

# %%
CITIES = {
    "roma"   : "rome_static_gtfs",
    "milano" : "mdb-2666-202609010101",
    "torino" : "mdb-2687-202609110053"
    }

# %%
GTFS_TABLES = [
    "stops",
    "routes", 
    "trips",
    "stop_times",
    "calendar",
    "calendar_dates"
    ]

# %%
CITIES_WITHOUT_CALENDAR = ["roma"]
